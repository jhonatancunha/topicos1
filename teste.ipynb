# %%
import numpy as np
import pandas as pd
import base64
import codecs
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
#pegar mensagem, mensagem completa, nome do repositorio onde o commit foi feito
data = pd.read_csv("data2.csv")
data
# Out:
#                                             repo  \
# 0        b"b'1160200515_jabref' b'JabRef_jabref'
# 1        b"b'1160200515_jabref' b'JabRef_jabref'
# 2        b"b'1160200515_jabref' b'JabRef_jabref'
# 3        b"b'1160200515_jabref' b'JabRef_jabref'
# 4        b"b'1160200515_jabref' b'JabRef_jabref'
# ...                                          ...
# 1048381             b"b'project-draco-hr_jabref'
# 1048382             b"b'project-draco-hr_jabref'
# 1048383             b"b'project-draco-hr_jabref'
# 1048384             b"b'project-draco-hr_jabref'
# 1048385             b"b'project-draco-hr_jabref'
#
#                                                   filename  \
# 0                                            .editorconfig
# 1                                           .gitattributes
# 2                                                  .github
# 3                                               .gitignore
# 4                                                 .mailmap
# ...                                                    ...
# 1048381  src_main_java_net_sf_jabref_gui_HtmlTransferab...
# 1048382  src_main_java_net_sf_jabref_gui_IconComparator...
# 1048383  src_main_java_net_sf_jabref_gui_ImportInspecti...
# 1048384  src_main_java_net_sf_jabref_gui_IsMarkedCompar...
# 1048385     src_main_java_net_sf_jabref_gui_MainTable.java
#
#                                                author  \
# 0                      1160200515 <1937453602@qq.com>
# 1                      1160200515 <1937453602@qq.com>
# 2                      1160200515 <1937453602@qq.com>
# 3                      1160200515 <1937453602@qq.com>
# 4                      1160200515 <1937453602@qq.com>
# ...                                               ...
# 1048381  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048382  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048383  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048384  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048385  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
#
#                        authored_at  \
# 0        2018-07-10 18:57:14+08:00
# 1        2018-07-10 18:57:14+08:00
# 2        2018-07-10 18:57:14+08:00
# 3        2018-07-10 18:57:14+08:00
# 4        2018-07-10 18:57:14+08:00
# ...                            ...
# 1048381  2015-07-28 16:04:44+02:00
# 1048382  2015-07-28 16:04:44+02:00
# 1048383  2015-07-28 16:04:44+02:00
# 1048384  2015-07-28 16:04:44+02:00
# 1048385  2015-07-28 16:04:44+02:00
#
#                                             committer  \
# 0                      1160200515 <1937453602@qq.com>
# 1                      1160200515 <1937453602@qq.com>
# 2                      1160200515 <1937453602@qq.com>
# 3                      1160200515 <1937453602@qq.com>
# 4                      1160200515 <1937453602@qq.com>
# ...                                               ...
# 1048381  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048382  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048383  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048384  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048385  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
#
#                       committed_at                                       sha  \
# 0        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 1        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 2        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 3        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 4        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# ...                            ...                                       ...
# 1048381  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048382  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048383  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048384  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048385  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
#
#                                       message
# 0                b'Zml4LWZvci1pc3N1ZS00MTEz'"
# 1                b'Zml4LWZvci1pc3N1ZS00MTEz'"
# 2                b'Zml4LWZvci1pc3N1ZS00MTEz'"
# 3                b'Zml4LWZvci1pc3N1ZS00MTEz'"
# 4                b'Zml4LWZvci1pc3N1ZS00MTEz'"
# ...                                       ...
# 1048381  b'TWV0aG9kIG5hbWUgcmVmYWN0b3Jpbmc='"
# 1048382  b'TWV0aG9kIG5hbWUgcmVmYWN0b3Jpbmc='"
# 1048383  b'TWV0aG9kIG5hbWUgcmVmYWN0b3Jpbmc='"
# 1048384  b'TWV0aG9kIG5hbWUgcmVmYWN0b3Jpbmc='"
# 1048385  b'TWV0aG9kIG5hbWUgcmVmYWN0b3Jpbmc='"
#
# [1048386 rows x 8 columns]

# %%
def decode_msg(message):
    try:
        return base64.b64decode(message[2:-1:]).decode('utf-8')
    except:
        return message[2:-1:]


data['message'] = data['message'].apply(lambda row: decode_msg(row))
data
# Out:
#                                             repo  \
# 0        b"b'1160200515_jabref' b'JabRef_jabref'
# 1        b"b'1160200515_jabref' b'JabRef_jabref'
# 2        b"b'1160200515_jabref' b'JabRef_jabref'
# 3        b"b'1160200515_jabref' b'JabRef_jabref'
# 4        b"b'1160200515_jabref' b'JabRef_jabref'
# ...                                          ...
# 1048381             b"b'project-draco-hr_jabref'
# 1048382             b"b'project-draco-hr_jabref'
# 1048383             b"b'project-draco-hr_jabref'
# 1048384             b"b'project-draco-hr_jabref'
# 1048385             b"b'project-draco-hr_jabref'
#
#                                                   filename  \
# 0                                            .editorconfig
# 1                                           .gitattributes
# 2                                                  .github
# 3                                               .gitignore
# 4                                                 .mailmap
# ...                                                    ...
# 1048381  src_main_java_net_sf_jabref_gui_HtmlTransferab...
# 1048382  src_main_java_net_sf_jabref_gui_IconComparator...
# 1048383  src_main_java_net_sf_jabref_gui_ImportInspecti...
# 1048384  src_main_java_net_sf_jabref_gui_IsMarkedCompar...
# 1048385     src_main_java_net_sf_jabref_gui_MainTable.java
#
#                                                author  \
# 0                      1160200515 <1937453602@qq.com>
# 1                      1160200515 <1937453602@qq.com>
# 2                      1160200515 <1937453602@qq.com>
# 3                      1160200515 <1937453602@qq.com>
# 4                      1160200515 <1937453602@qq.com>
# ...                                               ...
# 1048381  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048382  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048383  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048384  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048385  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
#
#                        authored_at  \
# 0        2018-07-10 18:57:14+08:00
# 1        2018-07-10 18:57:14+08:00
# 2        2018-07-10 18:57:14+08:00
# 3        2018-07-10 18:57:14+08:00
# 4        2018-07-10 18:57:14+08:00
# ...                            ...
# 1048381  2015-07-28 16:04:44+02:00
# 1048382  2015-07-28 16:04:44+02:00
# 1048383  2015-07-28 16:04:44+02:00
# 1048384  2015-07-28 16:04:44+02:00
# 1048385  2015-07-28 16:04:44+02:00
#
#                                             committer  \
# 0                      1160200515 <1937453602@qq.com>
# 1                      1160200515 <1937453602@qq.com>
# 2                      1160200515 <1937453602@qq.com>
# 3                      1160200515 <1937453602@qq.com>
# 4                      1160200515 <1937453602@qq.com>
# ...                                               ...
# 1048381  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048382  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048383  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048384  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048385  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
#
#                       committed_at                                       sha  \
# 0        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 1        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 2        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 3        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 4        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# ...                            ...                                       ...
# 1048381  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048382  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048383  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048384  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048385  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
#
#                          message
# 0             fix-for-issue-4113
# 1             fix-for-issue-4113
# 2             fix-for-issue-4113
# 3             fix-for-issue-4113
# 4             fix-for-issue-4113
# ...                          ...
# 1048381  Method name refactoring
# 1048382  Method name refactoring
# 1048383  Method name refactoring
# 1048384  Method name refactoring
# 1048385  Method name refactoring
#
# [1048386 rows x 8 columns]

# %%
def get_extension(row):
  return row.split(".")[-1]

data['extension'] = data['filename'].apply(lambda row: get_extension(row))
data
# Out:
#                                             repo  \
# 0        b"b'1160200515_jabref' b'JabRef_jabref'
# 1        b"b'1160200515_jabref' b'JabRef_jabref'
# 2        b"b'1160200515_jabref' b'JabRef_jabref'
# 3        b"b'1160200515_jabref' b'JabRef_jabref'
# 4        b"b'1160200515_jabref' b'JabRef_jabref'
# ...                                          ...
# 1048381             b"b'project-draco-hr_jabref'
# 1048382             b"b'project-draco-hr_jabref'
# 1048383             b"b'project-draco-hr_jabref'
# 1048384             b"b'project-draco-hr_jabref'
# 1048385             b"b'project-draco-hr_jabref'
#
#                                                   filename  \
# 0                                            .editorconfig
# 1                                           .gitattributes
# 2                                                  .github
# 3                                               .gitignore
# 4                                                 .mailmap
# ...                                                    ...
# 1048381  src_main_java_net_sf_jabref_gui_HtmlTransferab...
# 1048382  src_main_java_net_sf_jabref_gui_IconComparator...
# 1048383  src_main_java_net_sf_jabref_gui_ImportInspecti...
# 1048384  src_main_java_net_sf_jabref_gui_IsMarkedCompar...
# 1048385     src_main_java_net_sf_jabref_gui_MainTable.java
#
#                                                author  \
# 0                      1160200515 <1937453602@qq.com>
# 1                      1160200515 <1937453602@qq.com>
# 2                      1160200515 <1937453602@qq.com>
# 3                      1160200515 <1937453602@qq.com>
# 4                      1160200515 <1937453602@qq.com>
# ...                                               ...
# 1048381  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048382  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048383  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048384  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048385  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
#
#                        authored_at  \
# 0        2018-07-10 18:57:14+08:00
# 1        2018-07-10 18:57:14+08:00
# 2        2018-07-10 18:57:14+08:00
# 3        2018-07-10 18:57:14+08:00
# 4        2018-07-10 18:57:14+08:00
# ...                            ...
# 1048381  2015-07-28 16:04:44+02:00
# 1048382  2015-07-28 16:04:44+02:00
# 1048383  2015-07-28 16:04:44+02:00
# 1048384  2015-07-28 16:04:44+02:00
# 1048385  2015-07-28 16:04:44+02:00
#
#                                             committer  \
# 0                      1160200515 <1937453602@qq.com>
# 1                      1160200515 <1937453602@qq.com>
# 2                      1160200515 <1937453602@qq.com>
# 3                      1160200515 <1937453602@qq.com>
# 4                      1160200515 <1937453602@qq.com>
# ...                                               ...
# 1048381  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048382  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048383  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048384  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048385  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
#
#                       committed_at                                       sha  \
# 0        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 1        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 2        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 3        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 4        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# ...                            ...                                       ...
# 1048381  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048382  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048383  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048384  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048385  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
#
#                          message      extension
# 0             fix-for-issue-4113   editorconfig
# 1             fix-for-issue-4113  gitattributes
# 2             fix-for-issue-4113         github
# 3             fix-for-issue-4113      gitignore
# 4             fix-for-issue-4113        mailmap
# ...                          ...            ...
# 1048381  Method name refactoring           java
# 1048382  Method name refactoring           java
# 1048383  Method name refactoring           java
# 1048384  Method name refactoring           java
# 1048385  Method name refactoring           java
#
# [1048386 rows x 9 columns]

# %%
def teste(row):
  a = row[2::].split()
  result = []

  for i in a:
    result.append(i[2:-1:])

  return " ".join(result)

data["repo"] = data["repo"].apply(lambda row: teste(row))

# %%
data
# Out:
#                                     repo  \
# 0        1160200515_jabref JabRef_jabref
# 1        1160200515_jabref JabRef_jabref
# 2        1160200515_jabref JabRef_jabref
# 3        1160200515_jabref JabRef_jabref
# 4        1160200515_jabref JabRef_jabref
# ...                                  ...
# 1048381          project-draco-hr_jabref
# 1048382          project-draco-hr_jabref
# 1048383          project-draco-hr_jabref
# 1048384          project-draco-hr_jabref
# 1048385          project-draco-hr_jabref
#
#                                                   filename  \
# 0                                            .editorconfig
# 1                                           .gitattributes
# 2                                                  .github
# 3                                               .gitignore
# 4                                                 .mailmap
# ...                                                    ...
# 1048381  src_main_java_net_sf_jabref_gui_HtmlTransferab...
# 1048382  src_main_java_net_sf_jabref_gui_IconComparator...
# 1048383  src_main_java_net_sf_jabref_gui_ImportInspecti...
# 1048384  src_main_java_net_sf_jabref_gui_IsMarkedCompar...
# 1048385     src_main_java_net_sf_jabref_gui_MainTable.java
#
#                                                author  \
# 0                      1160200515 <1937453602@qq.com>
# 1                      1160200515 <1937453602@qq.com>
# 2                      1160200515 <1937453602@qq.com>
# 3                      1160200515 <1937453602@qq.com>
# 4                      1160200515 <1937453602@qq.com>
# ...                                               ...
# 1048381  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048382  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048383  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048384  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048385  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
#
#                        authored_at  \
# 0        2018-07-10 18:57:14+08:00
# 1        2018-07-10 18:57:14+08:00
# 2        2018-07-10 18:57:14+08:00
# 3        2018-07-10 18:57:14+08:00
# 4        2018-07-10 18:57:14+08:00
# ...                            ...
# 1048381  2015-07-28 16:04:44+02:00
# 1048382  2015-07-28 16:04:44+02:00
# 1048383  2015-07-28 16:04:44+02:00
# 1048384  2015-07-28 16:04:44+02:00
# 1048385  2015-07-28 16:04:44+02:00
#
#                                             committer  \
# 0                      1160200515 <1937453602@qq.com>
# 1                      1160200515 <1937453602@qq.com>
# 2                      1160200515 <1937453602@qq.com>
# 3                      1160200515 <1937453602@qq.com>
# 4                      1160200515 <1937453602@qq.com>
# ...                                               ...
# 1048381  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048382  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048383  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048384  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
# 1048385  Joerg Lenhard <joerg.lenhard@uni-bamberg.de>
#
#                       committed_at                                       sha  \
# 0        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 1        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 2        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 3        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# 4        2018-07-10 18:57:14+08:00  34320c7ce43d22f048bd5ccbda9f9624e335b940
# ...                            ...                                       ...
# 1048381  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048382  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048383  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048384  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
# 1048385  2015-07-28 16:04:44+02:00  1fd75c198513442392ccadca43d824fb99eac32c
#
#                          message      extension
# 0             fix-for-issue-4113   editorconfig
# 1             fix-for-issue-4113  gitattributes
# 2             fix-for-issue-4113         github
# 3             fix-for-issue-4113      gitignore
# 4             fix-for-issue-4113        mailmap
# ...                          ...            ...
# 1048381  Method name refactoring           java
# 1048382  Method name refactoring           java
# 1048383  Method name refactoring           java
# 1048384  Method name refactoring           java
# 1048385  Method name refactoring           java
#
# [1048386 rows x 9 columns]

# %%
remove = ['java', 'js', 'ts' 'py', 'c', 'go', 'php', 'cpp', 'cs', 'r', 'rb', 'swift', 'rs', 'rlib']

# %%
authors = data['author'].drop_duplicates().to_list()
authors
# Out:
# ['1160200515 <1937453602@qq.com>',
#  '1160200515 <36831859+1160200515@users.noreply.github.com>',
#  '1160300208 <lzlghvbn@163.com>',
#  '1160300302 <1295536907@qq.com>',
#  '1160300305 <20361068@qq.com>',
#  '1160300311 <1399774753@qq.com>',
#  '1160300323 <2933488896@qq.com>',
#  '1160300420 <32875823+1160300420@users.noreply.github.com>',
#  '1160300420 <906135558@qq.com>',
#  '1160300509 <805045718@qq.com>',
#  '1160300522 <18846136651@163.com>',
#  '1160300607 <1160300607@stu.hit.edu.cn>',
#  '1160300608 <18846010223@163.com>',
#  '1160300614 <36831317+1160300614@users.noreply.github.com>',
#  '1160300712 <liting1723@163.com>',
#  '1160300909 <2426501743@qq.com>',
#  '1160300909 <36838562+1160300909@users.noreply.github.com>',
#  '1161140207zhengzhibin <2389513327@qq.com>',
#  '1190500618xionghongji <53402869+Joe11028@users.noreply.github.com>',
#  '125m125 <125m125@users.noreply.github.com>',
#  '1710082010@qq.com <1710082010@qq.com>',
#  '5kilian <5kilian@informatik.uni-hamburg.de>',
#  'Abhishek Rai (abhishekjr) <betheunique@users.noreply.github.com>',
#  'Abraham Polk <abepolk@gmail.com>',
#  'Adam Rehn <adam.rehn@my.jcu.edu.au>',
#  'Admir Obralija <admir.obralija@mathematik.uni-stuttgart.de>',
#  'Admir Obralija <admir@adob04>',
#  'Admir Obralija <admir@live.de>',
#  'Admir Obralija <obraliar@users.noreply.github.com>',
#  'Adrian Daerr <adaerr@users.sf.net>',
#  'Adrian Daerr <adrian.daerr@univ-paris-diderot.fr>',
#  'AidanM11 <41391775+AidanM11@users.noreply.github.com>',
#  'Akash Deep <akash1994deep@users.noreply.github.com>',
#  'Alain Vaucher <acvaucher@gmail.com>',
#  'Alan <68600416+Qiming-Liu@users.noreply.github.com>',
#  'Aleksandrs Gusevs <aleksandrs.gusevs@proofit.lv>',
#  'Aleksandrs Gusevs <gusevs.aleksandrs@gmail.com>',
#  'Alessio Pollero <alessiopollero@users.sf.net>',
#  'Alex Petrov <alex.petrov.vt@gmail.com>',
#  'Alexander Girgis <11259344+AlexanderGirgis@users.noreply.github.com>',
#  'Alexander Schmitt <alexander.schmitt.3@posteo.de>',
#  'AlexanderGirgis <11259344+AlexanderGirgis@users.noreply.github.com>',
#  'Alexsandro Lauber <alexlauber@outlook.com>',
#  'Ali <ali.ayan@hotmail.de>',
#  'Ali <alijakparov.kz@gmail.com>',
#  'Ali_Zhagparov <ali_zhagparov@epam.com>',
#  'Alick Zhao <alick9188@gmail.com>',
#  'Allison Sampaio <allisonsampaiox@gmail.com>',
#  'Aloofwisdom <58632091+Aloofwisdom@users.noreply.github.com>',
#  'Alver <alver@alver-1001PX.(none)>',
#  'Aly Mohamed <st159580@stud.uni-stuttgart.de>',
#  'Aman Jain <aman.jain01@sap.com>',
#  'Ambrogio Oliva <ambro2@users.noreply.github.com>',
#  'Amish Shah <shahamish150294@gmail.com>',
#  'Andreas Amann <a.amann@ucc.ie>',
#  'Andreas Buhr <andreas@andreasbuhr.de>',
#  'Andres Sanchez <asanchez@nearsoft.com>',
#  'Andrew <dreyskiy@gmail.com>',
#  'Andrew <kuncevich_andrei@mail.ru>',
#  'Andrew Collins <andrew.j.collins@gmail.com>',
#  'Andrew Kuncevich <kuncevich_andrei@mail.ru>',
#  'Andrew-Lev <dreyskiy@gmail.com>',
#  'Anh Nghia Tran <trananhnghia12@gmail.com>',
#  'Anita Armbruster <armbruan@gmail.com>',
#  'Antal K <antalk2@gmail.com>',
#  'Antonio Ribeiro <tonhogeek@gmail.com>',
#  'Apple Inc <no@mail>',
#  'Apurva Churi <42309636+apurvachuri@users.noreply.github.com>',
#  'Arbalest007 <patrick.lin.007@hotmail.com>',
#  'Aryan <amoha16@student.aau.dk>',
#  'AtrusRiven <alexander.schmitt.3@posteo.de>',
#  'Atul Kaushik <atul.kaushikim@gmail.com>',
#  'August Janse <augustj@kth.se>',
#  'Ayman Abdel Ghany <ayman.abdelghany@aurea.com>',
#  'Ayman Abdel Ghany <aymana.ghany@devfactory.com>',
#  'BJaroszkowski <54515221+BJaroszkowski@users.noreply.github.com>',
#  'BShaq <34344089+BShaq@users.noreply.github.com>',
#  'BShaq <bulinshaqiri@hotmail.com>',
#  'Balhau <balhau@balhau.net>',
#  'Bartosz J. Kaczkowski <bartosz.kaczkowski@gmail.com>',
#  'Bartosz Jaroszkowski <bjaroszkowski@gmail.com>',
#  'Bartosz Kaczkowski <bartosz.kaczkowski@gmail.com>',
#  'Baruch Oltman <42524526+Oltman-B@users.noreply.github.com>',
#  'Basil <62039344+BasilDimopoulos@users.noreply.github.com>',
#  'BenArou <72353723+BenArou@users.noreply.github.com>',
#  'Benedikt Tutzer <benedikt.tutzer@gmail.com>',
#  'Benedikt Tutzer <benedikt.tutzer@tuwien.ac.at>',
#  'Benedikt Tutzer <benedikt_tutzer@yahoo.de>',
#  'Benedikt Tutzer <btut@users.noreply.github.com>',
#  'Benja Gooder <benjamingooder@gmail.com>',
#  'Benjamin Koehler <benjaminkoehler89@gmail.com>',
#  'Benjamin Schroth <68321970+schrothbn@users.noreply.github.com>',
#  'Benjamin Schroth <benjamin.schroth@nlgshop.de>',
#  'Bharat Raghunathan <bharatraghunthan9767@gmail.com>',
#  'Bharath Shendre <shendrekbharath@gmail.com>',
#  'Bhargava Varadharajan <bhargavavaradh@gmail.com>',
#  'Bherwani Ayush <ayush.bherwani1998@gmail.com>',
#  'Binxin <binxin@kth.se>',
#  'BlueWokou <Stallord.gilchrist229@gmail.com>',
#  'Brainsucker92 <Brainsucker92@users.noreply.github.com>',
#  'Brainsucker92 <stscit21@hs-esslingen.de>',
#  'Braunch <braunch.dev@gmail.com>',
#  'Brian Quistorff <bquistorff@gmail.com>',
#  'Brittany <jiezheng5@gmail.com>',
#  'Bruno Nunes <43324383+brunocmo@users.noreply.github.com>',
#  'Bruno Nunes <brunocmo.nunes@gmail.com>',
#  'CAI Zhichun <54977532+braincident@users.noreply.github.com>',
#  'Caleb Tillman <caleb.tillman@gmail.com>',
#  'Caleb Tillman <cttillman@users.noreply.github.com>',
#  'CaptainDaVinci <yashkothari199767@gmail.com>',
#  'Carl <carl.goransson@gmail.com>',
#  'Carl Christian Snethlage <50491877+calixtus@users.noreply.github.com>',
#  'Carl Christian Snethlage <cc.snethlage@gmail.com>',
#  'Carlos Morales <carlosmorales777@gmail.com>',
#  'Carlos Silva <sabioes@gmail.com>',
#  'CarodePourtales <49019500+CarodePourtales@users.noreply.github.com>',
#  'Caroline de Pourtales <caro.de.pourtales@gmail.com>',
#  'Catarina Gomes <catarinag@gmail.com>',
#  'Catarina Gomes <catarinagomespt@users.noreply.github.com>',
#  'Chamod Shehanka <hcsperera@outlook.com>',
#  'Chelsey Ong <30564248+chelseyong@users.noreply.github.com>',
#  'Chelsey Ong <chelseyong@gmail.com>',
#  'Chris <cboyce376@gmail.com>',
#  'Chris Brown <christopheraaronbrown@gmail.com>',
#  'Christian Bartsch <bartsch.dev@gmail.com>',
#  'Christine Rosquist <rosquis@kth.se>',
#  'Christoph <cschwentker@gmail.com>',
#  'Christoph <siedlerkiller@gmail.com>',
#  'Christoph Hochreiner <ch.hochreiner@gmail.com>',
#  'Christoph Hochreiner <chochreiner@users.noreply.github.com>',
#  'Christoph S <christophs@Christophs-MBP.fritz.box>',
#  'Christoph_Br4un <st103981@stud.uni-stuttgart.de>',
#  'Christopher S. Lester <clester@ieee.org>',
#  'Clodoaldo Basaglia <clodoaldofonseca92@gmail.com>',
#  'Clodoaldo da Fonseca <clodoaldofonseca92@gmail.com>',
#  'ColinHex <71373524+colinhex@users.noreply.github.com>',
#  'Corey <carterlanham@yahoo.com>',
#  'Dan <64694785+daniel-price@users.noreply.github.com>',
#  'Daniel Mair <mairdl.dev@gmail.com>',
#  'Daniel Price <64694785+daniel-price@users.noreply.github.com>',
#  'Daniel Willian <d.willian_sc@hotmail.com>',
#  'Dario Safa <dario.akhavansafa@uzh.ch>',
#  'Daryl Arouchian <slyr91@gmail.com>',
#  'Davfon <davide.fontanella@uzh.ch>',
#  'David Johansson <david.johansson11@gmail.com>',
#  'David Stevens <davidstevens.nz@gmail.com>',
#  'David Stevens <dstevens@kth.se>',
#  'David Yu <Davyie@n130-p110.eduroam.kth.se>',
#  'Davide <45424678+Davfon@users.noreply.github.com>',
#  'Dawid <dawidmt@gmail.com>',
#  'Dawid Motyka <dawidm@users.noreply.github.com>',
#  'Dawid Motyka <dawidmt@gmail.com>',
#  'Dawid Owoc <47257983+dawidowoc@users.noreply.github.com>',
#  'Dawid Owoc <dawidowoc6@gmail.com>',
#  'Deepak <deepakkumar24196@gmail.com>',
#  'Deepak Kumar <deepakkumar24196@gmail.com>',
#  'Dennis Tschechlov <tschechlov.dev@gmail.com>',
#  'Dennis Tschechlov <tschechlovdev@gmail.com>',
#  'DevSiroukane <37413702+DevSiroukane@users.noreply.github.com>',
#  'Dilan Coss <dilanarma@hotmail.com>',
#  'Dilan Coss <eso31@users.noreply.github.com>',
#  'Domenico <cufalo@gmail.com>',
#  'Domenico Cufalo <cufalo@gmail.com>',
#  'Dominik Schrempf <dominik.schrempf@gmail.com>',
#  'Dominik Traczyk <dominik.traczyk@crosswordcybersecurity.com>',
#  'Dominik Voigt <Dominik.ingo.voigt@gmail.com>',
#  'Dominik Voigt <dominik.ingo.voigt@gmail.com>',
#  'DominikVoigt <43381984+DominikVoigt@users.noreply.github.com>',
#  'DominikVoigt <dominik.ingo.voigt@gmail.com>',
#  'Douglas Nassif Roma Junior <nassifrroma@gmail.com>',
#  'Eclipse Clean Up <kopp.dev+cleanup@github.com>',
#  'EduRibeiro00 <eribeiro306@gmail.com>',
#  'Eduard Braun <Eduard.Braun2@gmx.de>',
#  'Eduardo <eduardooliveira.1997@alunos.utfpr.edu.br>',
#  'Eduardo Ribeiro <38781152+EduRibeiro00@users.noreply.github.com>',
#  'Egon Willighagen <egon.willighagen@gmail.com>',
#  'Eiswindyeti <33135360+Eiswindyeti@users.noreply.github.com>',
#  'Erdem Derebasoglu <derebaba@users.noreply.github.com>',
#  'Eric Lau <919023+skeric@users.noreply.github.com>',
#  'Eric Lau <skeric@gmail.com>',
#  'EricLee543 <ericlee54@foxmail.com>',
#  'Escoul <yunrruca@gmail.com>',
#  'Ethan Harris <ethanwharris@gmail.com>',
#  'Ethan Harris <ewah1g13@soton.ac.uk>',
#  'Fabian Bauer <fmbba@web.de>',
#  'Fabio Marcos <fabiojava@hotmail.com>',
#  'Fancy Z <sciencezfx@tju.edu.cn>',
#  'Fancy Zhang <sciencezfx@tju.edu.cn>',
#  'Felipe <felipeminorelli@gmail.com>',
#  'Felipe Fronchetti <fronchettiemail@gmail.com>',
#  'Felipe Myose <felipemyose@hotmail.com>',
#  'Felix Berger <blat1@users.sf.net>',
#  'Felix Schnabel <fschnabel007@gmail.com>',
#  'Fernando Santagata <nando.santagata@gmail.com>',
#  'Fifi-wang <1437711608@qq.com>',
#  'Fifi-wang <57441955+Fifi-wang@users.noreply.github.com>',
#  'Fiyinfolu Eludire <17176053+faeludire@users.noreply.github.com>',
#  'Florian Beetz <8899552+florian-beetz@users.noreply.github.com>',
#  'Florian Beetz <f.beetz@outlook.de>',
#  'Florian Beetz <florian1.beetz@stud.uni-bamberg.de>',
#  'Francois Charette <firmicus@ankabut.net>',
#  'Frank Dierkes <dierkes@ifr.ing.tu-bs.de>',
#  'Frank Steimle <steimlfk@users.noreply.github.com>',
#  'Fred <breakfastfish@users.sf.net>',
#  'Fu188 <1712448038@qq.com>',
#  'Galileo Sartor <galileo.sartor@gmail.com>',
#  'Gan-Cheng <11812106@mail.sustech.edu.cn>',
#  'Gan-Cheng <63938745+Gan-Cheng@users.noreply.github.com>',
#  'Gena928 <GennadiyStakhovskiy@gmail.com>',
#  'Gennadiy <GennadiyStakhovskiy@gmail.com>',
#  'Gennadiy Stakhovskiy <GennadiyStakhovskiy@gmail.com>',
#  'Geoffrey Taerim Kim <32500641+taerim25@users.noreply.github.com>',
#  'Geoffrey Taerim Kim <taerim25@gmail.com>',
#  'George Liargkovas <=g.liargko@gmail.com>',
#  'George Liargkovas <t8180061@aueb.gr>',
#  'Giorgos Drosos <56369797+gdrosos@users.noreply.github.com>',
#  'Giorgos Drosos <t8180024@aueb.gr>',
#  'Giovanni <59294994+mind000@users.noreply.github.com>',
#  'Giovanni Caldarola <59294994+mind000@users.noreply.github.com>',
#  'Giovanni Caldarola <mind_000@yahoo.it>',
#  'Giovanni Fabiani <fabiani.giovanni@gmail.com>',
#  'Giri <ngiri@INTUL16886094b.corp.intuit.net>',
#  'Glenn Olsson <glennholsson@gmail.com>',
#  'Goutam Lavudiya <goutam_lavudiya@mentor.com>',
#  'Graeme Stewart <gdstewart@users.noreply.github.com>',
#  'Grzegorz <grzegorz.popiel@yahoo.com>',
#  'Grzegorz Popiel <grzegorz.popiel@yahoo.com>',
#  'Guilherme Henna <guihenna@gmail.com>',
#  'Hakan Duran <ehakanduran@gmail.com>',
#  'Hakan E. Duran <ehakanduran@gmail.com>',
#  'Harinda Samarasekara <harindaburndown@gmail.com>',
#  'HerrAachen <6626492+HerrAachen@users.noreply.github.com>',
#  'Hieu <jdinh_23@yahoo.com>',
#  'HifeFish <hife@gmx.de>',
#  'Hollyqqqqq <11712639@mail.sustech.edu.cn>',
#  'Hollyqqqqq <55199983+Hollyqqqqq@users.noreply.github.com>',
#  'Houssem <housi.housi2015@gmail.com>',
#  'Houssem Nasri <housi.housi2015@gmail.com>',
#  'Hussain Arif <hussain.arifkl@gmail.com>',
#  'Hussain Arif <hussainarifkl@gmail.com>',
#  'IfIWantedTo <70264377+IfIWantedTo@users.noreply.github.com>',
#  'IfIWantedTo <josephine.cane@gmx.de>',
#  'Igor Chernyavsky <chigle@gmail.com>',
#  'Igor Steinmacher <ifsteinm@yahoo.com.br>',
#  'Igor Steinmacher <igorfs@utfpr.edu.br>',
#  'Igor Steinmacher <igorsteinmacher@gmail.com>',
#  'Illes Solt <illes@gravityrd.com>',
#  'Ingvar Jackal <rz703a@gmail.com>',
#  'Isaac <jisaacroles@gmail.com>',
#  'Isaac Roles <71780917+IsaacRoles@users.noreply.github.com>',
#  'Isaac Saito <Isaac.Saito@evistajet.com>',
#  'Isabel Beckenbach <Isabel.Beckenbach@fiz-karlsruhe.de>',
#  'Italo Santos <italo_07_@hotmail.com>',
#  'J.Pfeifer <julian.pfeifer.88@gmail.com>',
#  'JabRef <developers@jabref.org>',
#  'JabRef refresh journal lists [bot] <jabrefmail+webfeedback@gmail.com>',
#  'Jackson Ryan <jackson.baker.ryan@gmail.com>',
#  'Jan Frederik Maas <jfmaas@gmx.de>',
#  'Jan Kubovy <jan@kubovy.eu>',
#  'Jan Kubovy <jkubovy@faw.jku.at>',
#  'Janosch Kutscherauer <noshky@users.sf.net>',
#  'Jason Pickering <jason.p.pickering@gmail.com>',
#  'Jasper Vandemalle <jasper.vandemalle@gmail.com>',
#  'Jeff Kerr <jefferykerrison@gmail.com>',
#  'Jeffrey Sander <jeffreysander@gmail.com>',
#  'Joerg Lenhard <joerg.lenhard@kau.se>',
#  'Joerg Lenhard <joerg.lenhard@uni-bamberg.de>']

# %%
df_authors = pd.DataFrame()



for name in tqdm(authors):
    contributions_from_one_author = data.loc[data['author'] == name]
    display(contributions_from_one_author)
    break
    # display(contributions_from_one_author["extension"].value_counts())
    # sorted_contributions_from_one_author = contributions_from_one_author.sort_values(by="authored_at", ascending=True)
    # amount_of_commits = sorted_contributions_from_one_author.shape[0]
        
    # df_authors = df_authors.append(pd.DataFrame([[name, amount_of_commits]], columns=['author','qtd_commits']),ignore_index = True)
# Out:
#   0%|          | 0/267 [00:00<?, ?it/s]
#                                repo             filename  \
# 0   1160200515_jabref JabRef_jabref        .editorconfig
# 1   1160200515_jabref JabRef_jabref       .gitattributes
# 2   1160200515_jabref JabRef_jabref              .github
# 3   1160200515_jabref JabRef_jabref           .gitignore
# 4   1160200515_jabref JabRef_jabref             .mailmap
# ..                              ...                  ...
# 66  1160200515_jabref JabRef_jabref     jabref.install4j
# 67  1160200515_jabref JabRef_jabref  localization.gradle
# 68  1160200515_jabref JabRef_jabref      settings.gradle
# 69  1160200515_jabref JabRef_jabref       snapcraft.yaml
# 70  1160200515_jabref JabRef_jabref           xjc.gradle
#
#                             author                authored_at  \
# 0   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# 1   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# 2   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# 3   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# 4   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# ..                             ...                        ...
# 66  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
# 67  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
# 68  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
# 69  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
# 70  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
#
#                          committer               committed_at  \
# 0   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# 1   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# 2   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# 3   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# 4   1160200515 <1937453602@qq.com>  2018-07-10 18:57:14+08:00
# ..                             ...                        ...
# 66  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
# 67  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
# 68  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
# 69  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
# 70  1160200515 <1937453602@qq.com>  2018-07-14 16:27:37+08:00
#
#                                          sha  \
# 0   34320c7ce43d22f048bd5ccbda9f9624e335b940
# 1   34320c7ce43d22f048bd5ccbda9f9624e335b940
# 2   34320c7ce43d22f048bd5ccbda9f9624e335b940
# 3   34320c7ce43d22f048bd5ccbda9f9624e335b940
# 4   34320c7ce43d22f048bd5ccbda9f9624e335b940
# ..                                       ...
# 66  97dfb870e8c8a1452265eae3088dcdb736a740c0
# 67  97dfb870e8c8a1452265eae3088dcdb736a740c0
# 68  97dfb870e8c8a1452265eae3088dcdb736a740c0
# 69  97dfb870e8c8a1452265eae3088dcdb736a740c0
# 70  97dfb870e8c8a1452265eae3088dcdb736a740c0
#
#                                               message      extension
# 0                                  fix-for-issue-4113   editorconfig
# 1                                  fix-for-issue-4113  gitattributes
# 2                                  fix-for-issue-4113         github
# 3                                  fix-for-issue-4113      gitignore
# 4                                  fix-for-issue-4113        mailmap
# ..                                                ...            ...
# 66  Merge branch 'fix-for-issue-4113' of https://g...      install4j
# 67  Merge branch 'fix-for-issue-4113' of https://g...         gradle
# 68  Merge branch 'fix-for-issue-4113' of https://g...         gradle
# 69  Merge branch 'fix-for-issue-4113' of https://g...           yaml
# 70  Merge branch 'fix-for-issue-4113' of https://g...         gradle
#
# [71 rows x 9 columns]
#   0%|          | 0/267 [00:00<?, ?it/s]

# %%
df_authors
# Out:
#                                                 author  qtd_commits
# 0                       1160200515 <1937453602@qq.com>            4
# 1    1160200515 <36831859+1160200515@users.noreply....            2
# 2                        1160300208 <lzlghvbn@163.com>           21
# 3                       1160300302 <1295536907@qq.com>            4
# 4                         1160300305 <20361068@qq.com>            4
# ..                                                 ...          ...
# 262    Jasper Vandemalle <jasper.vandemalle@gmail.com>          122
# 263              Jeff Kerr <jefferykerrison@gmail.com>            9
# 264           Jeffrey Sander <jeffreysander@gmail.com>           41
# 265               Joerg Lenhard <joerg.lenhard@kau.se>          841
# 266       Joerg Lenhard <joerg.lenhard@uni-bamberg.de>          364
#
# [267 rows x 2 columns]

# %%
#pegar autores entre com mais de 8 commits
author_more_8_commits = df_authors[df_authors['qtd_commits'] >= 8]
author_more_8_commits = author_more_8_commits.sort_values(by="qtd_commits", ascending=False)
max_commits = author_more_8_commits.iloc[0]['qtd_commits']
min_commits = 0

# %%
from matplotlib import colors

hehe = np.random.rand(1, 9)
hehe[0][0] = 0
hehe[0][1] = 0
hehe[0][2] = 0
hehe[0][3] = 0
hehe[0][4] = 0
hehe[0][5] = 0
hehe[0][6] = 0
hehe[0][7] = 0
hehe[0][8] = 1

cmap = colors.ListedColormap(['red', 'blue', 'green'])

fig, ax = plt.subplots()
ax.imshow(hehe, cmap=cmap)

# draw gridlines
ax.set_xticks(np.arange(0, 20, 1))
ax.set_yticks(np.arange(0, 1, 1))

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_9181/3862107824.py in <module>
# ----> 1 data[1]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
